# %%
# Clone the repository so that the source files are available in Colab
# !git clone https://github.com/KUMARAGURU-V-S/Lab-experiments.git
import os
os.chdir('Lab-experiments/COMPILER-DESIGN/Experiment-10-Backend-Compiler-8086')

# %%
# Install necessary libraries for Lex/Yacc (flex and bison)
# !sudo apt-get update
# !sudo apt-get install flex bison

# %%
# Compile the code
# !gcc backend.c

# %%
# Run the compiled executable
# (You can provide input directly in the output cell if prompted)
# !./a.out
